# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import requests
import json
import time

# %%
# change this
my_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..RwiuSLIULpPX-eLczPhoEFbvEwgRtrxRcKRCyFrXBYI"

# %%
def get_planning_area(lat, lng, token=my_token):
    url = "https://developers.onemap.sg/privateapi/popapi/getPlanningarea"
    params = {"token":token, "lat": lat, "lng": lng, "year":2014}
    res = requests.get(url, params)
    try:
        data = res.json()[0]
        return data['pln_area_n']
    except:
        return None

# %%
get_planning_area(1.3, 103.8)
# Out:
# 'QUEENSTOWN'

# %%
get_planning_area(1.396006, 103.887595)
# Out:
# 'SENGKANG'

# %%
def get_all_planning_areas(token=my_token, year=2014):
    url = "https://developers.onemap.sg/privateapi/popapi/getPlanningareaNames"
    params = {'token':token, 'year':year}
    res = requests.get(url, params)
    planning_area_list = []
    for r in res.json():
        planning_area_list.append(r['pln_area_n'])
    return planning_area_list

# %%
planning_area_list = get_all_planning_areas()
print(planning_area_list)
print(len(planning_area_list))
# Out:
# ['ANG MO KIO', 'BEDOK', 'BISHAN', 'BOON LAY', 'BUKIT BATOK', 'BUKIT MERAH', 'CHOA CHU KANG', 'BUKIT PANJANG', 'JURONG EAST', 'QUEENSTOWN', 'JURONG WEST', 'BUKIT TIMAH', 'CENTRAL WATER CATCHMENT', 'CHANGI', 'CHANGI BAY', 'TENGAH', 'CLEMENTI', 'GEYLANG', 'HOUGANG', 'PIONEER', 'PUNGGOL', 'SELETAR', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'SIMPANG', 'SOUTHERN ISLANDS', 'SUNGEI KADUT', 'TAMPINES', 'TANGLIN', 'TOA PAYOH', 'TUAS', 'WESTERN ISLANDS', 'WESTERN WATER CATCHMENT', 'WOODLANDS', 'YISHUN', 'DOWNTOWN CORE', 'MARINA EAST', 'MARINA SOUTH', 'MUSEUM', 'NEWTON', 'ORCHARD', 'OUTRAM', 'KALLANG', 'LIM CHU KANG', 'MANDAI', 'MARINE PARADE', 'NORTH-EASTERN ISLANDS', 'NOVENA', 'PASIR RIS', 'PAYA LEBAR', 'RIVER VALLEY', 'ROCHOR', 'SINGAPORE RIVER', 'STRAITS VIEW']
# 55

# %%
sorted(planning_area_list)
# Out:
# ['ANG MO KIO',
#  'BEDOK',
#  'BISHAN',
#  'BOON LAY',
#  'BUKIT BATOK',
#  'BUKIT MERAH',
#  'BUKIT PANJANG',
#  'BUKIT TIMAH',
#  'CENTRAL WATER CATCHMENT',
#  'CHANGI',
#  'CHANGI BAY',
#  'CHOA CHU KANG',
#  'CLEMENTI',
#  'DOWNTOWN CORE',
#  'GEYLANG',
#  'HOUGANG',
#  'JURONG EAST',
#  'JURONG WEST',
#  'KALLANG',
#  'LIM CHU KANG',
#  'MANDAI',
#  'MARINA EAST',
#  'MARINA SOUTH',
#  'MARINE PARADE',
#  'MUSEUM',
#  'NEWTON',
#  'NORTH-EASTERN ISLANDS',
#  'NOVENA',
#  'ORCHARD',
#  'OUTRAM',
#  'PASIR RIS',
#  'PAYA LEBAR',
#  'PIONEER',
#  'PUNGGOL',
#  'QUEENSTOWN',
#  'RIVER VALLEY',
#  'ROCHOR',
#  'SELETAR',
#  'SEMBAWANG',
#  'SENGKANG',
#  'SERANGOON',
#  'SIMPANG',
#  'SINGAPORE RIVER',
#  'SOUTHERN ISLANDS',
#  'STRAITS VIEW',
#  'SUNGEI KADUT',
#  'TAMPINES',
#  'TANGLIN',
#  'TENGAH',
#  'TOA PAYOH',
#  'TUAS',
#  'WESTERN ISLANDS',
#  'WESTERN WATER CATCHMENT',
#  'WOODLANDS',
#  'YISHUN']

# %%
def get_populations(planning_area_list, token=my_token, year=2021):
    population_dict = {}
    for area in planning_area_list:
        url = "https://developers.onemap.sg/privateapi/popapi/getPopulationAgeGroup"
        params = {'token':token, 'year':year, 'planningArea':area}
        res = requests.get(url, params)
        data = res.json()[0]
        children = data['age_0_4']+data['age_5_9']+data['age_10_14']+data['age_15_19']
        adults = data['age_20_24']+data['age_25_29']+data['age_30_34']+data['age_35_39']+data['age_40_44']+data['age_45_49']+data['age_50_54']+data['age_55_59']+data['age_60_64']
        seniors = data['age_65_69']+data['age_70_74']+data['age_75_79']+data['age_80_84']+data['age_85_over']
        total = data['total']
        
        population_dict[area] = {"total":total, "children":children, "adults":adults, "seniors": seniors}
    return population_dict

# %%
pop_dict_2020 = get_populations(planning_area_list, year=2020)
print(pop_dict_2020)
# Out:
# {'ANG MO KIO': {'total': 162280, 'children': 26010, 'adults': 101040, 'seniors': 35220}, 'BEDOK': {'total': 134210, 'children': 24420, 'adults': 85420, 'seniors': 24370}, 'BISHAN': {'total': 87320, 'children': 15440, 'adults': 55840, 'seniors': 16040}, 'BOON LAY': {'total': 0, 'children': 0, 'adults': 0, 'seniors': 0}, 'BUKIT BATOK': {'total': 77480, 'children': 15730, 'adults': 51420, 'seniors': 10360}, 'BUKIT MERAH': {'total': 151250, 'children': 25240, 'adults': 92710, 'seniors': 33310}, 'CHOA CHU KANG': {'total': 192070, 'children': 40570, 'adults': 131440, 'seniors': 20070}, 'BUKIT PANJANG': {'total': 68150, 'children': 14660, 'adults': 45180, 'seniors': 8340}, 'JURONG EAST': {'total': 78600, 'children': 13100, 'adults': 50530, 'seniors': 14960}, 'QUEENSTOWN': {'total': 95930, 'children': 16570, 'adults': 59040, 'seniors': 20310}, 'JURONG WEST': {'total': 130840, 'children': 26700, 'adults': 86730, 'seniors': 17420}, 'BUKIT TIMAH': {'total': 77860, 'children': 17830, 'adults': 4
# ...

# %%
pop_df = pd.DataFrame.from_dict(pop_dict_2020, orient='index')
pop_df
# Out:
#                           total  children  adults  seniors
# ANG MO KIO               162280     26010  101040    35220
# BEDOK                    134210     24420   85420    24370
# BISHAN                    87320     15440   55840    16040
# BOON LAY                      0         0       0        0
# BUKIT BATOK               77480     15730   51420    10360
# BUKIT MERAH              151250     25240   92710    33310
# CHOA CHU KANG            192070     40570  131440    20070
# BUKIT PANJANG             68150     14660   45180     8340
# JURONG EAST               78600     13100   50530    14960
# QUEENSTOWN                95930     16570   59040    20310
# JURONG WEST              130840     26700   86730    17420
# BUKIT TIMAH               77860     17830   46960    13090
# CENTRAL WATER CATCHMENT       0         0       0        0
# CHANGI                     1850       530    1140      190
# CHANGI BAY                    0         0       0        0
# ...

# %% [markdown]
# ## Working on nodes

# %%
pop_df = pd.read_csv('data/population_2020.csv', index_col=0)
pop_df
# Out:
#                           total  children  adults  seniors
# ANG MO KIO               162280     26010  101040    35220
# BEDOK                    134210     24420   85420    24370
# BISHAN                    87320     15440   55840    16040
# BOON LAY                      0         0       0        0
# BUKIT BATOK               77480     15730   51420    10360
# BUKIT MERAH              151250     25240   92710    33310
# CHOA CHU KANG            192070     40570  131440    20070
# BUKIT PANJANG             68150     14660   45180     8340
# JURONG EAST               78600     13100   50530    14960
# QUEENSTOWN                95930     16570   59040    20310
# JURONG WEST              130840     26700   86730    17420
# BUKIT TIMAH               77860     17830   46960    13090
# CENTRAL WATER CATCHMENT       0         0       0        0
# CHANGI                     1850       530    1140      190
# CHANGI BAY                    0         0       0        0
# ...

# %%
with open('data/train_station_full_info.json', 'r') as f:
    train_data = json.load(f)
with open('data/bus_stop_full_info.json', 'r') as f:
    bus_data = json.load(f)

# %%
len(train_data), len(bus_data)
# Out:
# (166, 5075)

# %%
bus_stats = {'id':[], 'lat':[], 'lng':[], 'planningArea':[], 'tap_in':[], 'tap_out':[]}
for key, val in bus_data.items():
    try:
        bus_stats['tap_in'].append(5*sum(val['weekdays']['tap_in'])+2*sum(val['weekends']['tap_in']))
        bus_stats['tap_out'].append(5*sum(val['weekdays']['tap_out'])+2*sum(val['weekends']['tap_out']))
    except:
        continue
    bus_stats['id'].append(key)
    bus_stats['lat'].append(val['Latitude'])
    bus_stats['lng'].append(val['Longitude'])

# %%
len(bus_stats['id'])
# Out:
# 5056

# %%
# %%time
planningAreas = {}
failed_indexes = []
for i in bus_stats['id']:
    temp = get_planning_area(bus_data[i]['Latitude'], bus_data[i]['Longitude'])
    if temp is None:
        print(i, bus_data[i]['Latitude'], bus_data[i]['Longitude'])
        failed_indexes.append(i)
    else:
        planningAreas[i] = temp
    time.sleep(0.5)  # to prevent exceeding api limit
# Out:
# 42311 1.33865749997067 103.76028055601957
# 43611 1.3440783607984 103.75829172450743
# 43181 1.34648944401178 103.75681722199707
# 63351 1.36922638899711 103.88786388897049
# 60209 1.32986133945973 103.86896099565628
# 60179 1.32634025655419 103.86834025123765
# 60039 1.31996473842763 103.86983042567824
# 07379 1.31017336740849 103.86338225534827
# 01219 1.30526598535719 103.86072019914616
# 01239 1.30291236608351 103.86161817611134
# 01231 1.3032499999752 103.8610830559663
# 01311 1.3070916463394 103.86219695240973
# 60011 1.31471795031338 103.86376795493321
# 60021 1.31828596087227 103.86669874193286
# 60031 1.3204097072077 103.87007832529532
# 60229 1.32258108743147 103.87024013608315
# 60159 1.32409476572475 103.86764196002876
# 60201 1.32933888886 103.8683861111429
# 60261 1.33132471594343 103.86891794930561
# 61119 1.335623 103.871938
# 63349 1.36687207146588 103.88923358520269
# 02169 1.29333836780589 103.86070849052753
# 66041 1.3557230306281 103.8697219448858
# ...

# %%
len(planningAreas)
# Out:
# 1937

# %%
len(failed_indexes)
# Out:
# 277

# %%
failed_indexes = [i for i in bus_stats['id'] if i not in planningAreas]
len(failed_indexes)
# Out:
# 58

# %%
failed_indexes_2 = []
for i in failed_indexes:
    temp = get_planning_area(bus_data[i]['Latitude'], bus_data[i]['Longitude'])
    if temp is None:
        print(i, bus_data[i]['Latitude'], bus_data[i]['Longitude'])
        failed_indexes_2.append(i)
    else:
        planningAreas[i] = temp
    time.sleep(0.5)  # to prevent exceeding api limit
# Out:
# 46211 1.46491732433248 103.76547712149443
# 47711 1.46345834112565 103.76442341207213
# 46219 1.4654268105665 103.76826657164715
# 46239 1.49390379286364 103.74403292148666

# %%
len(failed_indexes_2), len(planningAreas)
# Out:
# (4, 5052)

# %%
bus_stats['planningArea'] = []
for i, k in enumerate(bus_stats['id']):
    bus_stats['planningArea'].append(planningAreas.get(k, None))
len(bus_stats['planningArea'])
# Out:
# 5056

# %%
bus_df = pd.DataFrame.from_dict(bus_stats, orient='columns')
bus_df.head()
# Out:
#       id       lat         lng planningArea   tap_in  tap_out
# 0  75009  1.354076  103.943391     TAMPINES  4607736  4502560
# 1  76059  1.352962  103.941652     TAMPINES   330559   116454
# 2  76069  1.348753  103.942086     TAMPINES   310013   204128
# 3  96289  1.340055  103.948381     TAMPINES   144639   312525
# 4  96109  1.337371  103.950673     TAMPINES    74787   104606

# %%
bus_df.to_csv('data/bus_planning_areas.csv')

# %%
bus_df.describe()
# Out:
#                lat          lng        tap_in       tap_out
# count  5056.000000  5056.000000  5.056000e+03  5.056000e+03
# mean      1.351788   103.823915  7.589601e+04  7.589586e+04
# std       0.045306     0.084930  2.057332e+05  1.940642e+05
# min       1.251427   103.617250  0.000000e+00  0.000000e+00
# 25%       1.317717   103.761976  1.052900e+04  1.146775e+04
# 50%       1.344786   103.833185  3.346500e+04  3.499700e+04
# 75%       1.379373   103.888791  8.054525e+04  8.136775e+04
# max       1.493904   104.015614  6.393645e+06  5.536337e+06

# %%
bus_df['deficit'] = bus_df['tap_in'] - bus_df['tap_out']
bus_df.head()
# Out:
#       id       lat         lng planningArea   tap_in  tap_out  deficit
# 0  75009  1.354076  103.943391     TAMPINES  4607736  4502560   105176
# 1  76059  1.352962  103.941652     TAMPINES   330559   116454   214105
# 2  76069  1.348753  103.942086     TAMPINES   310013   204128   105885
# 3  96289  1.340055  103.948381     TAMPINES   144639   312525  -167886
# 4  96109  1.337371  103.950673     TAMPINES    74787   104606   -29819

# %%
bus_df['deficit'].describe()
# Out:
# count    5.056000e+03
# mean     1.552611e-01
# std      8.753570e+04
# min     -1.757191e+06
# 25%     -1.557225e+04
# 50%     -1.555000e+02
# 75%      1.479375e+04
# max      1.304202e+06
# Name: deficit, dtype: float64

# %%
bus_df['avg_flow'] = (bus_df['tap_in'] + bus_df['tap_out'])//2
bus_df.head()
# Out:
#       id       lat         lng planningArea   tap_in  tap_out  deficit  \
# 0  75009  1.354076  103.943391     TAMPINES  4607736  4502560   105176
# 1  76059  1.352962  103.941652     TAMPINES   330559   116454   214105
# 2  76069  1.348753  103.942086     TAMPINES   310013   204128   105885
# 3  96289  1.340055  103.948381     TAMPINES   144639   312525  -167886
# 4  96109  1.337371  103.950673     TAMPINES    74787   104606   -29819
#
#    avg_flow
# 0   4555148
# 1    223506
# 2    257070
# 3    228582
# 4     89696

# %%
area_net_flow = bus_df.groupby(['planningArea'])['avg_flow'].sum()
area_net_flow
# Out:
# planningArea
# ANG MO KIO                 16855477
# BEDOK                      24555301
# BISHAN                      7620968
# BOON LAY                     749613
# BUKIT BATOK                12428188
# BUKIT MERAH                17159783
# BUKIT PANJANG               8384445
# BUKIT TIMAH                 6030480
# CENTRAL WATER CATCHMENT      466899
# CHANGI                      3133449
# CHANGI BAY                    10768
# CHOA CHU KANG              11833090
# CLEMENTI                   10741455
# DOWNTOWN CORE               4800605
# GEYLANG                    14972029
# HOUGANG                    19017298
# JURONG EAST                10253651
# JURONG WEST                24341261
# KALLANG                     9846998
# LIM CHU KANG                  45054
# MANDAI                       330471
# MARINA SOUTH                  19587
# MARINE PARADE               3930432
# MUSEUM                      1897757
# NEWTON                       816727
# ...

# %%
bus_df.dropna(inplace=True)

# %%
bus_df['pop_multiplier'] = bus_df.apply(lambda x: x['avg_flow']/area_net_flow[x['planningArea']], axis=1)
bus_df.head()
# Out:
#       id       lat         lng planningArea   tap_in  tap_out  deficit  \
# 0  75009  1.354076  103.943391     TAMPINES  4607736  4502560   105176
# 1  76059  1.352962  103.941652     TAMPINES   330559   116454   214105
# 2  76069  1.348753  103.942086     TAMPINES   310013   204128   105885
# 3  96289  1.340055  103.948381     TAMPINES   144639   312525  -167886
# 4  96109  1.337371  103.950673     TAMPINES    74787   104606   -29819
#
#    avg_flow  pop_multiplier
# 0   4555148        0.190125
# 1    223506        0.009329
# 2    257070        0.010730
# 3    228582        0.009541
# 4     89696        0.003744

# %%
bus_df['pop_estimate'] = bus_df.apply(lambda x: int(x['pop_multiplier']*pop_df['total'][x['planningArea']]), axis=1)
bus_df.head()
# Out:
#       id       lat         lng planningArea   tap_in  tap_out  deficit  \
# 0  75009  1.354076  103.943391     TAMPINES  4607736  4502560   105176
# 1  76059  1.352962  103.941652     TAMPINES   330559   116454   214105
# 2  76069  1.348753  103.942086     TAMPINES   310013   204128   105885
# 3  96289  1.340055  103.948381     TAMPINES   144639   312525  -167886
# 4  96109  1.337371  103.950673     TAMPINES    74787   104606   -29819
#
#    avg_flow  pop_multiplier  pop_estimate
# 0   4555148        0.190125         49413
# 1    223506        0.009329          2424
# 2    257070        0.010730          2788
# 3    228582        0.009541          2479
# 4     89696        0.003744           973

# %%
bus_df.describe()
# Out:
#                lat          lng        tap_in       tap_out       deficit  \
# count  5052.000000  5052.000000  5.052000e+03  5.052000e+03  5.052000e+03
# mean      1.351692   103.823965  7.568868e+04  7.555770e+04  1.309812e+02
# std       0.045197     0.084944  2.052204e+05  1.925318e+05  8.254844e+04
# min       1.251427   103.617250  0.000000e+00  0.000000e+00 -1.568385e+06
# 25%       1.317694   103.761976  1.052900e+04  1.146775e+04 -1.557225e+04
# 50%       1.344756   103.833315  3.343300e+04  3.495400e+04 -1.555000e+02
# 75%       1.379237   103.888836  8.051200e+04  8.133450e+04  1.479375e+04
# max       1.467570   104.015614  6.393645e+06  5.536337e+06  1.304202e+06
#
#            avg_flow  pop_multiplier  pop_estimate
# count  5.052000e+03    5.052000e+03   5052.000000
# mean   7.562295e+04    1.009501e-02    633.343824
# std    1.946494e+05    3.215305e-02   1889.063606
# min    1.000000e+01    4.173851e-07      0.000000
# ...

# %%
bus_df.to_csv('data/population_estimates.csv', index=False)
